# %%
city='RAICHUR'
city=city.title()
city
# Out:
# 'Raichur'

# %%
# Python program to find current  
# weather details of any city 
# using openweathermap api 
  
# import required modules 
import requests, json 
  
# Enter your API key here 
api_key = '263ded519ea442d9998aa79294fdae5d'
  
# base_url variable to store url 
base_url = "http://api.openweathermap.org/data/2.5/weather?"
  
# Give city name 
city_name = city
  
# complete_url variable to store 
# complete url address 
complete_url = base_url + "appid=" + api_key + "&q=" + city_name 
  
# get method of requests module 
# return response object 
response = requests.get(complete_url) 
  
# json method of response object  
# convert json format data into 
# python format data 
x = response.json() 
  
# Now x contains list of nested dictionaries 
# Check the value of "cod" key is equal to 
# "404", means city is found otherwise, 
# city is not found 
if x["cod"] != "404": 
  
    # store the value of "main" 
    # key in variable y 
    y = x["main"] 
  
    # store the value corresponding 
    # to the "temp" key of y 
    current_temperature = y["temp"] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
    current_pressure = y["pressure"] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
    current_humidiy = y["humidity"] 
  
    # store the value of "weather" 
    # key in variable z 
    z = x["weather"] 
  
    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
    weather_description = z[0]["description"] 
  
    # print following values 
    print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidiy) +
          "\n description = " +
                    str(weather_description)) 
  
else: 
    print(" City Not Found ")
# Out:
#  Temperature (in kelvin unit) = 302.53
#  atmospheric pressure (in hPa unit) = 1008
#  humidity (in percentage) = 72
#  description = light rain

# %%
list3=['overcast clouds',
'broken clouds',
'overcast clouds',
'Light rain and snow',
'Snow	Rain and snow',
'Snow	Light shower snow',
'Snow	Shower snow',
'Snow	Heavy shower snow',
'Rain']
var=str(weather_description)
if 'Heavy' in var or var in list3:
  f1.write('It will rain tomorrow, irrigation not required at all')
  print('It will rain tomorrow, irrigation not required at all')
elif 'rain' in var or var in list3:
  f1.write('It might rain tomorrow, irrigation with caution')
  print('It might rain tomorrow, irrigation with caution')
elif 'mist' in var or 'fog' in var:
    f1.write('IT is going to be misty and foggy, take necessary precautions')
    print('IT is going to be misty and foggy, take necessary precautions')
else:
  f1.write('irrigating is required')
  print('irrigating is recommended')
# Out:
# It might rain tomorrow, irrigation with caution

# %%
f1=open('/content/drive/My Drive/weather_data/output.txt','w')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
f1.close()
